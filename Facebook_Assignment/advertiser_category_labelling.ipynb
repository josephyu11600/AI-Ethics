# %%
import json
from collections import defaultdict
from google import genai
from dotenv import load_dotenv
import re

load_dotenv()
# Out:
# True

# %%
advertiser_file_path = './data/advertisers_using_your_activity_or_information.json'
with open(advertiser_file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

# %%
class AdvertiserClassifier:
    
    def __init__(self, advertiser_file_path: str):
        with open(advertiser_file_path, 'r', encoding='utf-8') as file:
            self.data = json.load(file)
        
        self.all_advertisers = self._get_advertisers_cleaned()
        self.gemini_client = genai.Client()
        self.categories = ["Shopping", "Technology", "Financial Services", "Entertainment", "Health", "Food", "Travel", "Education", "Miscellaneous"]
    
    def _get_advertisers_cleaned(self) -> list[str]:
        all_advertisers = [ad_map['value'] for ad_map in self.data['label_values'][0]['vec']]

        cleaned_advertisers = []
        for advertiser in all_advertisers:
            advertiser = advertiser.strip()
            advertiser = re.sub(r'[^A-Za-z0-9 ]+', '', advertiser)
            advertiser = advertiser.lower()
            if advertiser != '':
                cleaned_advertisers.append(advertiser)
        return cleaned_advertisers
    
    def _get_advertiser_batches(self, advertisers: list[str], batch_size: int = 30) -> list[list[str]]:
        batches = []
        for i in range(0, len(advertisers), batch_size):
            batches.append(advertisers[i:i + batch_size])
        return batches

    def _get_gemini_prompt(self, batch_advertisers: list[str], categories: list[str]) -> str:
        prompt = (
            "For each of the following advertisers, classify them into one of these categories: "
            + ", ".join(categories)
            + ".\n\n"
        )
        for adv in batch_advertisers:
            prompt += f"- {adv}\n"
        prompt += "\nProvide your answer in the format 'Advertiser: Category' with a newline after each one.\nDo not include any other text in your response.\n"
        prompt += "For any advertisers name that is not english or not commonly known or you are unsure about classify as Miscellaneous.\n"
        prompt += "If the advertiser does not clearly belong to any of the specified categories, classify it as Miscellaneous.\n"
        prompt += "Feel free to use online search to help with classification.\n"
        return prompt

    def _classify_batch(self, batch_advertisers: list[str], model_id: str) -> dict[str, str]:
        prompt = self._get_gemini_prompt(batch_advertisers, self.categories)
        response = self.gemini_client.models.generate_content(
            model=model_id, contents=prompt
        )
        if not response.text:
            raise ValueError("No response from Gemini API")
        
        response_text = response.text.strip()
        classifications = {}
        for line in response_text.split('\n'):
            if ': ' in line:
                adv, category = line.split(': ', 1)
                classifications[adv.strip()] = category.strip()
        return classifications

    def classify_all_advertisers_with_rate_limiting(self, qpm: int = 30, batch_size: int = 30, model_id: str = "gemini-2.0-flash-lite") -> dict[str, str]:
        import time
        from tqdm import tqdm

        advertiser_batches = self._get_advertiser_batches(self.all_advertisers, batch_size=batch_size)
        all_classifications = {}
        interval = 60 / qpm  

        for batch in tqdm(advertiser_batches, desc="Classifying advertisers"):
            try:
                batch_classifications = self._classify_batch(batch, model_id=model_id)
                all_classifications.update(batch_classifications)
            except Exception as e:
                print(f"Error classifying batch: {e}")
            time.sleep(interval)  # Rate limiting

        return all_classifications

# %%
advertiser_classifier = AdvertiserClassifier(advertiser_file_path)
classifications = advertiser_classifier.classify_all_advertisers_with_rate_limiting(qpm=10, batch_size=50, model_id="gemini-2.5-flash")
# Out:
# Classifying advertisers: 100%|██████████| 32/32 [11:49<00:00, 22.18s/it]

# %%
classifications
# Out:
# {'experian marketing services audiences': 'Technology',
#  'zorbas coney island': 'Food',
#  'oracle data cloud': 'Technology',
#  'cross screen media': 'Miscellaneous',
#  'doordash': 'Food',
#  'mediacom usa': 'Miscellaneous',
#  'omd usa': 'Miscellaneous',
#  'walmartcom': 'Retail',
#  'hearts science': 'Miscellaneous',
#  'alaska airlines': 'Travel',
#  'uniagency': 'Miscellaneous',
#  'bluefocus': 'Miscellaneous',
#  'jackpot party casino community': 'Entertainment',
#  'webpals mobile': 'Miscellaneous',
#  'yellowhead': 'Miscellaneous',
#  'xtreme xperience': 'Entertainment',
#  'meetsocial hk digital marketing coltd1': 'Miscellaneous',
#  'stripe': 'Financial Services',
#  'shopify': 'Technology',
#  'shein metaall': 'Fashion',
#  'jw pei int': 'Fashion',
#  'wp brandstudio': 'Miscellaneous',
#  'washington post': 'Entertainment',
#  'usa today': 'Entertainment',
#  'staypineapple hotels': 'Travel',
#  'vrbo': 'Travel',
#  'expedia': 'Travel',
#  'chicago loop alliance': 'Miscellaneous',
#  'clemenger bbdo': 'Miscellaneous',
#  'linkedin emea latam': 'Technology',
#  'linkedin': 'Technology',
#  'core fabrics': 'Retail',
#  'retro report': 'Entertainment',
#  'whitney': 'Entertainment',
#  'ds laboratories': 'Health',
#  'flower power': 'Miscellaneous',
#  'llbean': 'Retail',
#  'shop': 'Technology',
#  'aarp advocates': 'Miscellaneous',
#  'gmmb': 'Miscellaneous',
#  'aarp': 'Miscellaneous',
#  'vml': 'Miscellaneous',
#  'aarp driver safety': 'Education',
#  'aaa auto club enterprises': 'Travel',
#  'aaa club alliance': 'Travel',
#  'propsco': 'Miscellaneous',
#  'aaa oregonidaho': 'Travel',
#  'aaa mountain west group': 'Travel',
#  'aaa mwg smart home manager': 'Technology',
#  'media plus': 'Miscellaneous',
#  'aaa the auto club group': 'Travel',
#  'aaa northeast': 'Travel',
#  'aaa washington': 'Travel',
#  'aaa': 'Travel',
#  'aaa western and central new york': 'Travel',
#  'aaa south jersey': 'Travel',
#  'reach ireland': 'Entertainment',
#  'local world news': 'Entertainment',
#  'the mirror': 'Entertainment',
#  'onthemarketcom': 'Technology',
#  'reach ni': 'Entertainment',
#  'picturesongoldcom': 'Retail',
#  'turo': 'Technology',
#  'tripadvisor': 'Travel',
#  'abbvie us business manager': 'Health',
#  'vagina coach': 'Health',
#  'copacinofujikado': 'Miscellaneous',
#  'jolly capital llc': 'Financial Services',
#  'nasdaq': 'Financial Services',
#  'the home depot rm': 'Retail',
#  'ace hardware': 'Retail',
#  'moroch': 'Miscellaneous',
#  'lowes home improvement': 'Retail',
#  'the home depot': 'Retail',
#  'jackson perkins': 'Retail',
#  'daltons garden & landscape supplies': 'Retail',
#  'alice caroline ltd': 'Fashion',
#  'duckadilly': 'Fashion',
#  'etsy': 'Technology',
#  'mec': 'Retail',
#  'catalyst': 'Miscellaneous',
#  'brkthru': 'Miscellaneous',
#  'wmx': 'Entertainment',
#  'ebay': 'Technology',
#  'ebaycouk': 'Technology',
#  'ebay canada': 'Technology',
#  'division d': 'Miscellaneous',
#  'wsecu': 'Financial Services',
#  'otto insurance': 'Financial Services',
#  'joy wallet finance': 'Financial Services',
#  'canva': 'Technology',
#  'cabelas': 'Retail',
#  '360i': 'Miscellaneous',
#  'salesclix': 'Miscellaneous',
#  'rens pets': 'Retail',
#  'cole haan': 'Fashion',
#  'petsmart': 'Retail',
#  'omni social': 'Miscellaneous',
#  'omg outcomes canada': 'Miscellaneous',
#  'academy sports & outdoors': 'Retail',
#  'grupo presidente': 'Travel',
#  'fitness sf': 'Health',
#  'home eco grants': 'Miscellaneous',
#  'kickstarter': 'Financial Services',
#  'uber': 'Travel',
#  '10fc': 'Miscellaneous',
#  'sett': 'Miscellaneous',
#  'digitas north america': 'Miscellaneous',
#  'bighouse marketing': 'Miscellaneous',
#  'sotsu': 'Entertainment',
#  'databricks': 'Technology',
#  'abbvie': 'Health',
#  'fetch': 'Retail',
#  'yelp': 'Technology',
#  'offerup': 'Retail',
#  'life at meta': 'Technology',
#  'anthropic': 'Technology',
#  'sioux digital 11': 'Miscellaneous',
#  'adobe': 'Technology',
#  'contenidos el rey': 'Entertainment',
#  'strike social': 'Technology',
#  'vamp': 'Technology',
#  'adobe photoshop elements premiere elements': 'Technology',
#  'ah': 'Miscellaneous',
#  'the hershey company': 'Food',
#  'j3': 'Miscellaneous',
#  'opentable': 'Food',
#  'macys': 'Retail',
#  'liveramp': 'Technology',
#  'valentina': 'Miscellaneous',
#  'ror partners': 'Miscellaneous',
#  'top foodies just desserts': 'Food',
#  'drive toyota': 'Travel',
#  'hangukvegan': 'Food',
#  'nibbles pet credit card': 'Financial Services',
#  'epsilon audience data provider': 'Technology',
#  'ulta beauty': 'Retail',
#  'conill advertising': 'Miscellaneous',
#  'barkleyokrp': 'Miscellaneous',
#  'target': 'Retail',
#  'team one usa': 'Miscellaneous',
#  'car price secrets': 'Education',
#  'amc theatres': 'Entertainment',
#  'eyeota': 'Technology',
#  'gcommerce': 'Technology',
#  'brand survey': 'Miscellaneous',
#  'yelp yan': 'Technology',
#  'vera schmadecke vendas on line': 'Retail',
#  'acxiom': 'Technology',
#  'massage envy': 'Health',
#  'dfa media': 'Miscellaneous',
#  'initiative': 'Miscellaneous',
#  'deepsync labs': 'Technology',
#  'wiland data tactics': 'Miscellaneous',
#  'frit': 'Miscellaneous',
#  'purple': 'Retail',
#  'getyourguide': 'Travel',
#  'wiland audiences': 'Miscellaneous',
#  '4c': 'Technology',
#  'pointscom': 'Technology',
#  'adara': 'Technology',
#  'gopuff': 'Retail',
#  'omd entertainment': 'Miscellaneous',
#  'cybba': 'Technology',
#  'placeiq2': 'Technology',
#  'carhartt': 'Fashion',
#  'williams sonoma': 'Retail',
#  'nogin': 'Technology',
#  'share txt': 'Technology',
#  'coegi': 'Miscellaneous',
#  'wyndham hotels resorts': 'Travel',
#  'chewy': 'Retail',
#  'reality labs': 'Technology',
#  'foursquare city guide': 'Technology',
#  'hellofresh': 'Food',
#  'next vacay': 'Travel',
#  'data axle': 'Technology',
#  'bayer aspirin': 'Health',
#  'hard rock hotel cancun': 'Travel',
#  'santander bank us': 'Financial Services',
#  'deep root analytics': 'Miscellaneous',
#  'albertsons': 'Retail',
#  'windfall data': 'Financial Services',
#  'uniqlo usa': 'Fashion',
#  'stay wear': 'Miscellaneous',
#  'zoominfo': 'Technology',
#  'ford motor company': 'Retail',
#  'fritolay brands': 'Food',
#  'sephora': 'Retail',
#  'um ny': 'Miscellaneous',
#  'freshdesk': 'Technology',
#  'sue mclean and associates': 'Miscellaneous',
#  'meta': 'Technology',
#  'we are saatchi': 'Miscellaneous',
#  'ripndip': 'Fashion',
#  'bed bath beyond': 'Retail',
#  'bubly': 'Food',
#  'cvs pharmacy': 'Health',
#  'hbo max': 'Entertainment',
#  'datonics': 'Technology',
#  'ohmconnect': 'Technology',
#  'nordstrom': 'Retail',
#  'test page': 'Miscellaneous',
#  'the elf on the shelf': 'Entertainment',
#  'airbnb': 'Travel',
#  'wiland data targeting': 'Technology',
#  'creo': 'Miscellaneous',
#  'eab enrollment services': 'Education',
#  'progressive': 'Financial Services',
#  'audience town': 'Technology',
#  'skyvu inc': 'Entertainment',
#  'dbrand': 'Technology',
#  'chamberlain coffee': 'Food',
#  'yelp audiences': 'Technology',
#  'throtle integrations': 'Technology',
#  'starcom usa': 'Miscellaneous',
#  'best buy': 'Retail',
#  'iprospect detroit': 'Miscellaneous',
#  'hallmark': 'Entertainment',
#  'masterclass': 'Education',
#  'ja resorts hotels': 'Travel',
#  'tory burch': 'Fashion',
#  'linqia': 'Technology',
#  'dsplus': 'Technology',
#  'hockerty': 'Fashion',
#  'omnet llc': 'Miscellaneous',
#  'rezonate media': 'Miscellaneous',
#  'bush brothers company': 'Food',
#  'tha agc 1000': 'Miscellaneous',
#  'columbia sportswear': 'Fashion',
#  'topo designs': 'Fashion',
#  'claremont graduate university': 'Education',
#  'walgreens': 'Health',
#  'horizon therapeutics': 'Health',
#  'optimal': 'Technology',
#  'frontier airlines': 'Travel',
#  'dentsux north america us': 'Miscellaneous',
#  'brand polling': 'Miscellaneous',
#  '100058842247195 2': 'Miscellaneous',
#  'net conversion': 'Miscellaneous',
#  'calvin klein': 'Fashion',
#  'ws na': 'Miscellaneous',
#  'within': 'Miscellaneous',
#  'asana': 'Technology',
#  'fulton roark': 'Fashion',
#  'purple media': 'Miscellaneous',
#  'bilt business manager': 'Financial Services',
#  'spotify': 'Entertainment',
#  'regis university': 'Education',
#  'health union llc': 'Health',
#  'groupm nexus bm2 wpp nl': 'Miscellaneous',
#  'preflect ads': 'Miscellaneous',
#  'supplyx': 'Technology',
#  'egglands best eggs': 'Food',
#  'ticketmaster': 'Entertainment',
#  'michaels stores': 'Retail',
#  'att audience business manager': 'Technology',
#  'the lenox hotel boston': 'Travel',
#  'endless pools': 'Health',
#  'semcasting inc': 'Technology',
#  'glassdoor': 'Technology',
#  'drive with lyft': 'Travel',
#  'walt disney world': 'Entertainment',
#  'too good to go': 'Food',
#  'reingold': 'Miscellaneous',
#  'o segredo das blogueiras': 'Miscellaneous',
#  'hashtagpinpoint corporation': 'Technology',
#  'oracle data cloud ca': 'Technology',
#  'shareably': 'Entertainment',
#  'adidas': 'Fashion',
#  'applebees': 'Food',
#  'viator': 'Travel',
#  'samsonite': 'Travel',
#  'metlife': 'Financial Services',
#  'the essence vault': 'Fashion',
#  'lionsback resort': 'Travel',
#  'butlertill': 'Technology',
#  'nerdwallet': 'Financial Services',
#  'lululemon': 'Fashion',
#  'dynata advertising solutions': 'Technology',
#  'redfin': 'Technology',
#  'carbon arc': 'Miscellaneous',
#  'nike': 'Fashion',
#  'adparlor': 'Technology',
#  'blizzard': 'Entertainment',
#  'drop': 'Retail',
#  'local kitchens': 'Food',
#  'fb app': 'Technology',
#  'geico': 'Financial Services',
#  'ad pros': 'Miscellaneous',
#  'a24': 'Entertainment',
#  'ihg hotels resorts': 'Travel',
#  'spark foundry usa': 'Miscellaneous',
#  'rebecca hefner author': 'Entertainment',
#  'otta': 'Technology',
#  'spark foundry': 'Miscellaneous',
#  'lange': 'Miscellaneous',
#  'm1m media': 'Miscellaneous',
#  'figs': 'Health',
#  'criteo us': 'Technology',
#  'chase': 'Financial Services',
#  'merkle data partner': 'Technology',
#  'guinness': 'Food',
#  'fandango': 'Entertainment',
#  'brilliantorg': 'Education',
#  'eulerity': 'Technology',
#  'my symple loan': 'Financial Services',
#  'mejuri': 'Fashion',
#  'aurora global holdings': 'Miscellaneous',
#  'share data': 'Technology',
#  'jtb': 'Travel',
#  'para bellum public affairs': 'Miscellaneous',
#  'goat': 'Retail',
#  'l15004saisurendarmaharaj sharma 3 bm5': 'Miscellaneous',
#  'intuit turbotax': 'Financial Services',
#  'essence': 'Entertainment',
#  'lumen technologies': 'Technology',
#  'ask embla': 'Miscellaneous',
#  'kroger': 'Retail',
#  'blue state': 'Miscellaneous',
#  'vaynermedia': 'Miscellaneous',
#  'farmers insurance': 'Financial Services',
#  'delta air lines': 'Travel',
#  'dollar general': 'Retail',
#  'illinois lottery': 'Entertainment',
#  'hq cdm': 'Miscellaneous',
#  'basis technologies': 'Technology',
#  'jambys': 'Fashion',
#  'discover': 'Financial Services',
#  'unidays': 'Education',
#  'alistersent': 'Miscellaneous',
#  'travel alberta reprise': 'Travel',
#  'canada goose': 'Fashion',
#  'mullenlowe us': 'Miscellaneous',
#  'draftkings': 'Entertainment',
#  'kohls': 'Retail',
#  'polne': 'Miscellaneous',
#  'zapier': 'Technology',
#  'wbci': 'Entertainment',
#  'crossmedia': 'Miscellaneous',
#  'some slight clothing': 'Fashion',
#  'mileiq': 'Technology',
#  'bm xmdn 202': 'Miscellaneous',
#  'temple denver': 'Entertainment',
#  'lithia motors': 'Retail',
#  'arz group': 'Miscellaneous',
#  'twice': 'Entertainment',
#  'the twilight saga': 'Entertainment',
#  'wiland data strategies': 'Technology',
#  'blue bottle coffee': 'Food',
#  'macys men': 'Retail',
#  'tambourine': 'Miscellaneous',
#  'targetsmart': 'Technology',
#  'motorola': 'Technology',
#  'furniture appliancemart': 'Retail',
#  'whaleco inc': 'Retail',
#  'kbmg data services development': 'Technology',
#  'neuapp': 'Technology',
#  'bm 5 250 567200': 'Miscellaneous',
#  'parents': 'Miscellaneous',
#  'ea electronic arts': 'Entertainment',
#  'flight club': 'Fashion',
#  'brand networks': 'Technology',
#  'room board': 'Retail',
#  'dny': 'Miscellaneous',
#  'gupta media': 'Miscellaneous',
#  'coach': 'Fashion',
#  'indeed': 'Miscellaneous',
#  'smiledirectclub': 'Health',
#  'parks project': 'Fashion',
#  'typeform': 'Technology',
#  'savvy by shopmium': 'Food',
#  'kepler': 'Miscellaneous',
#  'xfinity': 'Technology',
#  'fp1 strategies': 'Miscellaneous',
#  'team elatos': 'Miscellaneous',
#  '511 tactical': 'Fashion',
#  'performance marketing usd spotify ab': 'Entertainment',
#  'croud ads': 'Miscellaneous',
#  'hmi social': 'Miscellaneous',
#  'the classic tshirt company': 'Fashion',
#  'bloomingdales': 'Retail',
#  'amazoncom': 'Retail',
#  'slimfast': 'Health',
#  'kalamazoo outdoor gourmet': 'Retail',
#  'phathom pharmaceuticals': 'Health',
#  'premier bankcard': 'Financial Services',
#  '247ai target platform': 'Technology',
#  'uscellular': 'Technology',
#  'regions bank': 'Financial Services',
#  'paypal': 'Financial Services',
#  'discover the palm beaches': 'Travel',
#  'lda': 'Miscellaneous',
#  'fanatics': 'Retail',
#  'lendio': 'Financial Services',
#  'betty crocker': 'Food',
#  'betterment': 'Financial Services',
#  'publiccom': 'Financial Services',
#  'rwest': 'Miscellaneous',
#  'predictive media analytics llc': 'Miscellaneous',
#  'topgolf': 'Entertainment',
#  'bath body works': 'Retail',
#  'callaway preowned': 'Retail',
#  'powdr': 'Travel',
#  'havas media group usa llc': 'Miscellaneous',
#  'left hook': 'Miscellaneous',
#  'bang productions television': 'Entertainment',
#  'way to quit': 'Health',
#  'the atlanta journalconstitution': 'Entertainment',
#  'gm012': 'Miscellaneous',
#  'blue chip distributors inc': 'Miscellaneous',
#  'len di len di': 'Miscellaneous',
#  'dr pepper snapple group': 'Food',
#  'ramp': 'Financial Services',
#  'drexel university': 'Education',
#  'the woobles': 'Retail',
#  'popsycle digital marketing': 'Miscellaneous',
#  'performics test page': 'Miscellaneous',
#  'hopper': 'Travel',
#  'zulily': 'Retail',
#  'disney streaming': 'Entertainment',
#  'apple services': 'Technology',
#  'mpp business test account': 'Miscellaneous',
#  'regal': 'Entertainment',
#  'synchrony': 'Financial Services',
#  'channel factory': 'Miscellaneous',
#  'drunk elephant skin care': 'Health',
#  'precisetarget': 'Miscellaneous',
#  'deputycom': 'Technology',
#  'cendyn': 'Technology',
#  'tommy hilfiger': 'Fashion',
#  'puzzmo': 'Entertainment',
#  'snapchat for business': 'Technology',
#  'sarah hamilton rn': 'Health',
#  'navy federal credit union': 'Financial Services',
#  'papa johns pizza': 'Food',
#  'l15008 bm5 maicol garcia 4': 'Miscellaneous',
#  'makeawish america': 'Miscellaneous',
#  'indigo sports golf management': 'Travel',
#  'nielsen marketing cloud': 'Technology',
#  'rent solutions': 'Miscellaneous',
#  'ltstyle89195': 'Miscellaneous',
#  'progress': 'Technology',
#  'medthink inc': 'Health',
#  'dr livingood': 'Health',
#  'resonate': 'Technology',
#  'kashable': 'Financial Services',
#  'amc': 'Entertainment',
#  'sage dental': 'Health',
#  'norton': 'Technology',
#  'my health teams': 'Health',
#  'under the canopy': 'Retail',
#  'goodway tier 3 digital': 'Miscellaneous',
#  'the breakers palm beach': 'Travel',
#  'the points guy': 'Travel',
#  'toms': 'Fashion',
#  'verizon': 'Technology',
#  'townsquare ignite': 'Miscellaneous',
#  'ashley': 'Retail',
#  'um apac': 'Miscellaneous',
#  'hero cosmetics': 'Health',
#  'the north face': 'Fashion',
#  'katalyst advantage': 'Technology',
#  'a place for mom': 'Health',
#  'hong kong zoom interactive network marketing technology limited': 'Miscellaneous',
#  'celonis': 'Technology',
#  'lionsgate': 'Entertainment',
#  'wish': 'Retail',
#  'gocar tours': 'Travel',
#  'intuit smb medialabs': 'Technology',
#  'um amex': 'Miscellaneous',
#  'the shipyard crew': 'Miscellaneous',
#  'spotify latam bm': 'Entertainment',
#  'inventrio': 'Technology',
#  'illcurrency': 'Miscellaneous',
#  '223 cuboccdroga5': 'Miscellaneous',
#  'lumi labs': 'Food',
#  'adentro': 'Miscellaneous',
#  'mouratoglou tennis academy': 'Education',
#  'guitar center': 'Retail',
#  'retailmenot': 'Retail',
#  'ads preview workaround': 'Miscellaneous',
#  'bm5 old 17 04 2025 15 37 24': 'Miscellaneous',
#  'tmobile': 'Technology',
#  'united': 'Travel',
#  'diggerland usa': 'Entertainment',
#  'grubhub': 'Food',
#  'resolution media': 'Miscellaneous',
#  'novartis clinical trials': 'Health',
#  'hazel village': 'Retail',
#  'ranavat': 'Health',
#  'happy family organics': 'Food',
#  'powers interactive': 'Miscellaneous',
#  'crunchyroll': 'Entertainment',
#  'weee': 'Food',
#  'gogo lush': 'Fashion',
#  'ltstyle89198': 'Miscellaneous',
#  'opad media': 'Miscellaneous',
#  'mint mobile': 'Technology',
#  'vertodigital': 'Miscellaneous',
#  'coderpad': 'Technology',
#  'change research': 'Miscellaneous',
#  'fan365': 'Entertainment',
#  'hellatints': 'Miscellaneous',
#  'sephora single brand campaigns': 'Retail',
#  'alain dupetit': 'Fashion',
#  'aegis media innov8': 'Miscellaneous',
#  'paciolan': 'Technology',
#  'neon': 'Entertainment',
#  'respondio': 'Technology',
#  'umla': 'Miscellaneous',
#  'vitaly': 'Fashion',
#  'intuit mailchimp': 'Technology',
#  'nathan james home': 'Retail',
#  'extrategic culture': 'Miscellaneous',
#  'club champion': 'Retail',
#  'decode': 'Miscellaneous',
#  'gentscents': 'Fashion',
#  'protect socks': 'Fashion',
#  'universal studios hollywood': 'Entertainment',
#  'au 60': 'Miscellaneous',
#  'cmx': 'Technology',
#  'dc': 'Entertainment',
#  'the new york times': 'Entertainment',
#  'microsoft customer insights center': 'Technology',
#  'freya test account': 'Fashion',
#  'teddy fresh': 'Fashion',
#  'dominos pizza': 'Food',
#  'angler ai': 'Technology',
#  'nike mx': 'Fashion',
#  'usaa': 'Financial Services',
#  'incept': 'Miscellaneous',
#  'hanes': 'Fashion',
#  'delta vacations': 'Travel',
#  'youtheory': 'Health',
#  'dentsu x galderma': 'Health',
#  'cigna healthcare': 'Health',
#  'resortpass': 'Travel',
#  'iprospect us newyork': 'Miscellaneous',
#  'aim digital agency': 'Miscellaneous',
#  'at home': 'Retail',
#  'groupon inc': 'Retail',
#  'butcherbox': 'Food',
#  'elevation church': 'Miscellaneous',
#  'zeta': 'Technology',
#  'max connect digital': 'Miscellaneous',
#  'jcpenney': 'Retail',
#  'miq us': 'Technology',
#  'hilton newsroom': 'Travel',
#  'betterup': 'Education',
#  'pandamobo': 'Miscellaneous',
#  'credlize promotora': 'Financial Services',
#  'dong thanh': 'Miscellaneous',
#  'natrol': 'Health',
#  'merkle incorporated': 'Miscellaneous',
#  'coursera': 'Education',
#  'westerly coffee': 'Food',
#  'brooks running': 'Fashion',
#  'triumph capital': 'Financial Services',
#  'dc ipg': 'Miscellaneous',
#  'spigen': 'Technology',
#  'blaze pizza': 'Food',
#  'a lc al jaffar 1 bm350': 'Miscellaneous',
#  'canary': 'Technology',
#  'rei': 'Retail',
#  'audacy social conquest': 'Entertainment',
#  'healixglobal': 'Health',
#  'inspire sleep apnea innovation': 'Health',
#  'mercy for animals': 'Miscellaneous',
#  'udemy': 'Education',
#  'luminary roli ltd': 'Miscellaneous',
#  'ruggable': 'Retail',
#  'ohio 56906438': 'Miscellaneous',
#  'listerine': 'Health',
#  'cmi media group and compas': 'Miscellaneous',
#  'blue perigon digital': 'Miscellaneous',
#  'aerosoles': 'Fashion',
#  'bm350 whiter xmdn usa 4': 'Miscellaneous',
#  'carat usa': 'Miscellaneous',
#  'klarna': 'Financial Services',
#  'jsq group': 'Miscellaneous',
#  'tenx': 'Financial Services',
#  'ethos': 'Financial Services',
#  'zaiger llc': 'Miscellaneous',
#  'universal orlando resort': 'Entertainment',
#  'nowthis': 'Entertainment',
#  'swellshark': 'Miscellaneous',
#  'mri media pte ltd': 'Miscellaneous',
#  'university of portland': 'Education',
#  'bustle': 'Entertainment',
#  'projects watches': 'Fashion',
#  'gm007': 'Miscellaneous',
#  'lincoln': 'Technology',
#  'lands end': 'Retail',
#  'edx': 'Education',
#  'sams club': 'Retail',
#  'il homestores': 'Retail',
#  'imge': 'Miscellaneous',
#  'kingstone': 'Financial Services',
#  'linux foundation events': 'Technology',
#  'mec los angeles': 'Miscellaneous',
#  'tshirt kingdom b55': 'Retail',
#  'all day all night events': 'Entertainment',
#  'get up and go kayaking silver springs': 'Travel',
#  'adara business manager 2': 'Technology',
#  'sally beauty': 'Retail',
#  'club monaco': 'Fashion',
#  'disclosurefest': 'Entertainment',
#  'yami': 'Food',
#  'splunk': 'Technology',
#  'nextguest': 'Technology',
#  'shareability': 'Miscellaneous',
#  'sallie mae': 'Financial Services',
#  'handle the heat': 'Food',
#  'campaign adcloud': 'Technology',
#  'simon schuster': 'Entertainment',
#  'modco t2': 'Miscellaneous',
#  'docusign': 'Technology',
#  'nordstrom rack': 'Retail',
#  'butterflymx': 'Technology',
#  'amadeus digital customer delivery team': 'Technology',
#  'tbn': 'Entertainment',
#  'um detroit': 'Miscellaneous',
#  'motus consumer insights': 'Miscellaneous',
#  'yn': 'Miscellaneous',
#  'champs sports': 'Retail',
#  'audible': 'Entertainment',
#  'sleep galleria': 'Retail',
#  'wehavefurniture': 'Retail',
#  'c 2 store': 'Miscellaneous',
#  'veniceai': 'Technology',
#  'a lc eddy montero 2 bm350': 'Miscellaneous',
#  'good apple': 'Miscellaneous',
#  'revhaus media group': 'Miscellaneous',
#  'aero': 'Miscellaneous',
#  'screen pilot': 'Miscellaneous',
#  'i360 llc': 'Technology',
#  'alexis russell jewelry': 'Fashion',
#  'andrew drop 90hn': 'Miscellaneous',
#  'meow wolf': 'Entertainment',
#  'quick quack car wash': 'Miscellaneous',
#  'fedex': 'Miscellaneous',
#  'emt': 'Miscellaneous',
#  'facebook insertion orders': 'Technology',
#  'fandango at home': 'Entertainment',
#  'au 1 au 5 tool 5': 'Miscellaneous',
#  'acorns': 'Financial Services',
#  'lolavie': 'Fashion',
#  'enchant dallas': 'Entertainment',
#  '1440': 'Miscellaneous',
#  'dentsu digital inc': 'Miscellaneous',
#  'sharkninja': 'Retail',
#  'lucid motors': 'Technology',
#  'golden hippo': 'Financial Services',
#  'eos digital marketing': 'Miscellaneous',
#  'black lab brands': 'Miscellaneous',
#  'edikted': 'Fashion',
#  'advanced contextual': 'Technology',
#  'point b communications': 'Miscellaneous',
#  'lifevest insurance': 'Financial Services',
#  'beachlife festival': 'Entertainment',
#  'interesting engineering': 'Miscellaneous',
#  'huntington national bank': 'Financial Services',
#  'ddc testing': 'Health',
#  'jocalio': 'Fashion',
#  'apolloio': 'Technology',
#  'health care service corporation': 'Health',
#  'moments of truth': 'Miscellaneous',
#  'balance kimonos': 'Fashion',
#  'sermez inc': 'Miscellaneous',
#  'madison square garden': 'Entertainment',
#  'sojern': 'Travel',
#  'abstrakt crew': 'Miscellaneous',
#  'tset': 'Miscellaneous',
#  'metateam': 'Miscellaneous',
#  'digital ad guys': 'Miscellaneous',
#  'off the hook': 'Fashion',
#  'ancientcosmetics': 'Retail',
#  'dojomojo': 'Technology',
#  'the realreal': 'Fashion',
#  'drury hotels': 'Travel',
#  'surprise balloon': 'Miscellaneous',
#  'wabunka': 'Miscellaneous',
#  'dr squatch': 'Retail',
#  'sculpd': 'Retail',
#  'vpon ai big data group': 'Technology',
#  'zanagraphics': 'Miscellaneous',
#  'fred hutch': 'Health',
#  'nextdoor': 'Technology',
#  'drmtlgy': 'Retail',
#  'foot locker': 'Retail',
#  'allergan aesthetics': 'Health',
#  'mobility tools': 'Miscellaneous',
#  'international rescue committee': 'Miscellaneous',
#  'another tomorrow': 'Fashion',
#  'lumenad': 'Technology',
#  'wayfair': 'Retail',
#  'great northern': 'Miscellaneous',
#  'medexpress urgent care': 'Health',
#  'dish': 'Entertainment',
#  'guideline': 'Financial Services',
#  'bm2500 nlm xmdt': 'Miscellaneous',
#  'cynthia harmon': 'Miscellaneous',
#  'affordable dentures implants': 'Health',
#  'starboard advertising': 'Miscellaneous',
#  'adt': 'Technology',
#  'instacart': 'Food',
#  'coxnext': 'Technology',
#  'qa lead ad form': 'Miscellaneous',
#  'whatsapp': 'Technology',
#  'girls crew': 'Fashion',
#  'adult swim': 'Entertainment',
#  'the boppy company': 'Retail',
#  'circlelenses usa': 'Fashion',
#  'proof advertising': 'Miscellaneous',
#  'mindshare usa': 'Miscellaneous',
#  'sashka co bracelets': 'Fashion',
#  'clearchoice management': 'Health',
#  'wiland data audiences': 'Miscellaneous',
#  'best tshirt': 'Miscellaneous',
#  'whirlpool': 'Retail',
#  'san diego speed boat adventures': 'Travel',
#  'amica insurance': 'Financial Services',
#  'living spaces': 'Retail',
#  'omehome': 'Technology',
#  'el show de andres gutierrez': 'Financial Services',
#  'yojani boutique': 'Fashion',
#  'zenith usa': 'Miscellaneous',
#  'edjyusa': 'Miscellaneous',
#  'decoded advertising': 'Miscellaneous',
#  'a lc baby mi bm350': 'Miscellaneous',
#  'reprise es': 'Miscellaneous',
#  'apex exchange': 'Miscellaneous',
#  'publicis health media': 'Miscellaneous',
#  'imogenhenryj5uo': 'Miscellaneous',
#  'majority hunter': 'Miscellaneous',
#  'bm500 agc 2021 nlm': 'Miscellaneous',
#  '257': 'Miscellaneous',
#  'cbs': 'Entertainment',
#  'taketwo interactive': 'Entertainment',
#  'unite us': 'Health',
#  'nars cosmetics': 'Fashion',
#  'raconteur media': 'Miscellaneous',
#  'adriana ramos': 'Miscellaneous',
#  '2u': 'Education',
#  'le labo fragrances': 'Fashion',
#  'national geographic': 'Entertainment',
#  'el gouna golf': 'Travel',
#  'brex': 'Financial Services',
#  'the vintage frames company': 'Fashion',
#  'veterans united': 'Financial Services',
#  'join the many': 'Miscellaneous',
#  'byrdie': 'Fashion',
#  'intercontinental san antonio riverwalk an ihg hotel': 'Travel',
#  'quizlet': 'Education',
#  'south beach skin care inc': 'Health',
#  'blanc noir': 'Fashion',
#  'brinkley thompson': 'Miscellaneous',
#  'dan intel global': 'Technology',
#  'xy dng tc': 'Miscellaneous',
#  'capital one shopping': 'Financial Services',
#  'the galveston diet': 'Health',
#  'prettylitter': 'Health',
#  'zillow': 'Retail',
#  'sisense': 'Technology',
#  'smosh': 'Entertainment',
#  'yuguo': 'Miscellaneous',
#  'doge t01': 'Miscellaneous',
#  'valvetronic designs': 'Retail',
#  'lasso marketing': 'Miscellaneous',
#  'marie nicole clothing': 'Fashion',
#  'codecademy': 'Education',
#  'eversana intouch': 'Miscellaneous',
#  'iheartcountry': 'Entertainment',
#  'prx performance': 'Health',
#  'forbes media llc': 'Miscellaneous',
#  'auto glass now': 'Retail',
#  '1015 folsom': 'Entertainment',
#  'nexon america': 'Entertainment',
#  'edgefbigtest': 'Miscellaneous',
#  'nomad apparel co': 'Fashion',
#  'aliexpress': 'Retail',
#  'canvas lms': 'Education',
#  'matthew 626 llc': 'Miscellaneous',
#  'advictory': 'Miscellaneous',
#  'gap inc': 'Fashion',
#  'voyage travel marketing': 'Miscellaneous',
#  'suiler altamirano control': 'Miscellaneous',
#  'buckledown products': 'Retail',
#  'battleship iowa museum': 'Entertainment',
#  'autocamp': 'Travel',
#  'herschel supply company ltd': 'Fashion',
#  'apparel marketing': 'Miscellaneous',
#  'mens llc': 'Miscellaneous',
#  'openphone': 'Technology',
#  'klook': 'Travel',
#  'medscape': 'Health',
#  'polestar': 'Technology',
#  'notion': 'Technology',
#  'sourcery label': 'Miscellaneous',
#  'universal music canada': 'Entertainment',
#  'affinity answers': 'Miscellaneous',
#  'wantable': 'Fashion',
#  '100057938041609 1': 'Miscellaneous',
#  'um australia': 'Miscellaneous',
#  'dc global nlm 93': 'Miscellaneous',
#  'midlandusa': 'Technology',
#  'ciceron': 'Miscellaneous',
#  'bm350 whiter xmdn usa 8': 'Miscellaneous',
#  'questus': 'Miscellaneous',
#  'waymo': 'Technology',
#  'osume': 'Retail',
#  'huggies': 'Health',
#  'stitch fix': 'Fashion',
#  'merkleypartners': 'Miscellaneous',
#  'capy era llc': 'Miscellaneous',
#  'snow commerce': 'Retail',
#  'ttfb': 'Miscellaneous',
#  'liftengine': 'Miscellaneous',
#  'tdc audiences': 'Miscellaneous',
#  'wlc agency': 'Miscellaneous',
#  'madwell': 'Miscellaneous',
#  'neoperformance': 'Miscellaneous',
#  'frameio': 'Technology',
#  'deltahub': 'Retail',
#  'a lc jerson salazar bm5': 'Miscellaneous',
#  'dc global nlm 74': 'Miscellaneous',
#  'last data 02k5': 'Miscellaneous',
#  'bonobos': 'Fashion',
#  'core digital media': 'Miscellaneous',
#  'blue shield of california': 'Health',
#  'abd direct': 'Miscellaneous',
#  'revelo brasil': 'Miscellaneous',
#  'ski butlers': 'Travel',
#  'wake research': 'Health',
#  'group publishing': 'Education',
#  'click designs design for everyone': 'Technology',
#  'pratilipi hindi': 'Entertainment',
#  'heartbeat': 'Miscellaneous',
#  'saks fifth avenue': 'Fashion',
#  'zitsticka': 'Health',
#  'ewj agency': 'Miscellaneous',
#  'bsn': 'Health',
#  'seychelle media': 'Miscellaneous',
#  'trg': 'Miscellaneous',
#  'axos bank': 'Financial Services',
#  'vs0408universegold': 'Miscellaneous',
#  'gale partners llc': 'Miscellaneous',
#  'brightside': 'Health',
#  'boostmobile newpostharmony': 'Technology',
#  'passarelamulticulturalps': 'Miscellaneous',
#  'jowua taiwan': 'Technology',
#  'happy money': 'Financial Services',
#  'shiphero': 'Technology',
#  'taxi driver': 'Entertainment',
#  'thrive causemetics': 'Fashion',
#  'bm500 nlm kmq 27': 'Miscellaneous',
#  'mazda usa': 'Technology',
#  'bob hannon consulting': 'Miscellaneous',
#  'pushspring': 'Technology',
#  'justfab': 'Fashion',
#  'keurig': 'Food',
#  'up 104 anh 80100': 'Miscellaneous',
#  'reprise media': 'Miscellaneous',
#  'gamevn': 'Entertainment',
#  'randall reilly': 'Miscellaneous',
#  'resbiotic': 'Health',
#  'resolution agency': 'Miscellaneous',
#  'papershootofficial': 'Technology',
#  'mgo': 'Financial Services',
#  'petsmart charities': 'Miscellaneous',
#  'b c v social': 'Miscellaneous',
#  'rpa advertising': 'Miscellaneous',
#  'greenvillespartanburg international airport': 'Travel',
#  'vs 2306 dilge yldz': 'Miscellaneous',
#  'pintrill': 'Retail',
#  'cedar and vine': 'Miscellaneous',
#  'pili verse xmnd 246': 'Entertainment',
#  'beekeepers naturals': 'Health',
#  'disney books': 'Entertainment',
#  'sofi': 'Financial Services',
#  'state farm': 'Financial Services',
#  'aspen lisha': 'Miscellaneous',
#  'colgate connect': 'Health',
#  'au 6 au 10 tool 5': 'Miscellaneous',
#  'up 36': 'Miscellaneous',
#  'call of duty': 'Entertainment',
#  'spcshp': 'Miscellaneous',
#  'primitive skateboarding': 'Fashion',
#  'glorious pc gaming race': 'Technology',
#  'inspire brands': 'Food',
#  'p2 public affairs': 'Miscellaneous',
#  'dripdrop': 'Health',
#  'fastweb': 'Education',
#  'visa': 'Financial Services',
#  'visit savannah': 'Travel',
#  'orchard': 'Entertainment',
#  'agc 199': 'Miscellaneous',
#  'birdwell beach britches': 'Fashion',
#  'kalahari resorts conventions': 'Travel',
#  'neustar fb syndication': 'Technology',
#  'a lc jass reyes 3 bm350': 'Miscellaneous',
#  'four communications social media team': 'Miscellaneous',
#  'zaxbys': 'Food',
#  'lea waeckerle': 'Miscellaneous',
#  'hm paid social': 'Fashion',
#  'cute animals': 'Miscellaneous',
#  'capyeraonline': 'Miscellaneous',
#  'pacsun': 'Fashion',
#  'tombras': 'Miscellaneous',
#  'bravado': 'Entertainment',
#  'rally': 'Miscellaneous',
#  'up 76': 'Miscellaneous',
#  'burson global': 'Miscellaneous',
#  'the motley fool': 'Financial Services',
#  'st jude childrens research hospital': 'Health',
#  'cnbc': 'Financial Services',
#  'custom ink': 'Retail',
#  'veynd': 'Miscellaneous',
#  'gorjana': 'Fashion',
#  'magic': 'Miscellaneous',
#  'quick quack sucks': 'Miscellaneous',
#  'a lc danilo dela cruz 3': 'Miscellaneous',
#  'fbigstage': 'Miscellaneous',
#  'razer': 'Technology',
#  'linear 360': 'Miscellaneous',
#  'big lots': 'Retail',
#  'dean media': 'Miscellaneous',
#  'mars united commerce': 'Food',
#  'sandgrain studio': 'Miscellaneous',
#  'geometryhouse': 'Miscellaneous',
#  'step one foods': 'Food',
#  'extended stay america': 'Travel',
#  'bethesda': 'Entertainment',
#  'bm20': 'Miscellaneous',
#  'citeline': 'Health',
#  'city beauty': 'Fashion',
#  'financial educators network': 'Education',
#  'real chemistry': 'Health',
#  'tribe x': 'Miscellaneous',
#  'rubrik inc': 'Technology',
#  'wix': 'Technology',
#  'ruffalo noel levitz': 'Education',
#  'powertec': 'Health',
#  'old timey herald': 'Miscellaneous',
#  'capacity interactive digital marketing consulting for the arts': 'Entertainment',
#  'cas': 'Miscellaneous',
#  'the wildflower group': 'Miscellaneous',
#  'hometown dealer': 'Retail',
#  '99accs': 'Miscellaneous',
#  'accenture media console': 'Technology',
#  'strayer university': 'Education',
#  'world vision usa': 'Miscellaneous',
#  'quince': 'Retail',
#  'ads signals team': 'Technology',
#  'retargetly': 'Technology',
#  'asymm digital': 'Miscellaneous',
#  'a lc andi sinawan 1 bm350': 'Miscellaneous',
#  'freethink': 'Entertainment',
#  'ltstyle89199': 'Miscellaneous',
#  'pfizer inc': 'Health',
#  'first tube': 'Entertainment',
#  'sway creative labs': 'Miscellaneous',
#  'l15009 bm5 marcelo vasconcellos 2': 'Miscellaneous',
#  'supermetrics': 'Technology',
#  'open influence': 'Technology',
#  'jiu jitsu legacy': 'Education',
#  'the strategy group company': 'Miscellaneous',
#  'meta quest': 'Technology',
#  'rakuten': 'Miscellaneous',
#  'the yankee candle company': 'Retail',
#  'netspend': 'Financial Services',
#  'university of colorado boulder': 'Education',
#  'nutanix': 'Technology',
#  'softframe designs': 'Retail',
#  'national retail federation': 'Miscellaneous',
#  'shevick sales': 'Miscellaneous',
#  'truth': 'Health',
#  'piedmont park conservancy': 'Miscellaneous',
#  'turing': 'Technology',
#  'needwant': 'Retail',
#  'ymca of greater richmond': 'Health',
#  'dealerx': 'Technology',
#  'daily paper': 'Fashion',
#  'carnegie': 'Miscellaneous',
#  'voter participation center center for voter information': 'Miscellaneous',
#  'atlassian': 'Technology',
#  'req': 'Miscellaneous',
#  'aisle 518 strategies llc': 'Miscellaneous',
#  'blossom digital marketing': 'Miscellaneous',
#  'kcm test': 'Miscellaneous',
#  'kidoriman': 'Miscellaneous',
#  'academia dalva fitness': 'Health',
#  'iherb': 'Retail',
#  'vocal media': 'Technology',
#  'um canada': 'Miscellaneous',
#  'handshake': 'Technology',
#  'amsi': 'Miscellaneous',
#  'safelite': 'Miscellaneous',
#  'sawyer studios': 'Miscellaneous',
#  ...}

# %%
advertisers_labeled = {
    'advertisers': []
}

for adv, category in classifications.items():
    advertisers_labeled['advertisers'].append({
        'name': adv,
        'category': category
    })

with open('./data/targeted_advertisers_labeled.json', 'w', encoding='utf-8') as f:
    json.dump(advertisers_labeled, f, indent=4)
